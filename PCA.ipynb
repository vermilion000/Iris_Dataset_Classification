# %% [markdown]
# <a href="https://colab.research.google.com/github/vermilion000/Dataset_Classification/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import torch
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
data  = load_iris()
features = data["feature_names"]
target = data['target']
df = pd.DataFrame(data['data'],columns = features)

# %%
pca = PCA(n_components = 2)
p = pca.fit_transform(df,target)
# print(p.shape)
df_pca = pd.DataFrame(p,columns = ['pca1','pca2'])
df_pca['out'] = target

# %%
plt.figure(1)
plt.scatter(df_pca[(df_pca["out"]==0)])
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-695995876.py in <cell line: 0>()
#       1 plt.figure(1)
# ----> 2 plt.scatter(p[0],p[1],target)
#       3 plt.show
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3937     **kwargs,
#    3938 ) -> PathCollection:
# -> 3939     __ret = gca().scatter(
#    3940         x,
# ...

# %%
(df_pca["out"]==0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2589574513.py in <cell line: 0>()
# ----> 1 df_pca(df_pca["out"]==0)
#
# TypeError: 'DataFrame' object is not callable
